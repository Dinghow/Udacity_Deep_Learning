# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.224578
# Nearest to were: cannibalism, rhodes, disloyalty, pwnage, historic, alans, clarinetist, obstacle,
# Nearest to th: democratic, sedgwick, kinetic, gotland, litres, nubian, curds, ricardo,
# Nearest to most: lees, econometric, intriguing, port, cater, dnieper, crusaders, rationalism,
# Nearest to b: quotations, keyser, guards, toned, yf, varsity, wormhole, flourishes,
# Nearest to on: embattled, fortunate, mazes, demanded, henley, sargent, acetylcholine, wct,
# Nearest to state: conifers, stupid, aesthetically, esque, guitarists, mammoths, heavyweight, getting,
# Nearest to at: enosis, attenuation, carol, assimilated, starch, liner, ascetics, manley,
# Nearest to d: hall, totoro, detoxification, lune, accra, coates, mascarenes, heliports,
# Nearest to for: sexuality, flockhart, vara, har, invertebrate, cheering, wept, hessen,
# Nearest to a: model, zedong, involution, lowered, softer, fulltext, bsa, carts,
# Nearest to between: devonian, beneficent, warren, canids, insignificance, oersted, repay, sura,
# Nearest to see: dropped, gandhara, icrc, honorable, commutativity, spotlight, pastor, outermost,
# Nearest to such: communicative, earned, tumours, hagelin, sb, portsmouth, antlers, feign,
# Nearest to nine: sse, desiderius, foolish, bilingualism, gush, unload, moshe, glycoproteins,
# Nearest to many: intriguing, diomedes, crusaders, characters, underage, nomenclature, dinner, flips,
# Nearest to an: ics, chalukyas, patrolling, emanate, berthold, contraception, parlor, dracula,
# Average loss at step 2000: 4.366966
# Average loss at step 4000: 3.866793
# Average loss at step 6000: 3.789906
# Average loss at step 8000: 3.688513
# Average loss at step 10000: 3.621919
# Nearest to were: are, was, shipped, cannibalism, sternberg, have, hickman, tan,
# Nearest to th: four, litres, sedgwick, treads, democratic, guerilla, underwing, ricardo,
# Nearest to most: econometric, catherine, port, many, omri, jurists, incessant, facility,
# Nearest to b: varsity, and, mame, d, flats, abbe, keyser, phane,
# Nearest to on: in, amphibian, afterthought, timeless, from, sharpe, of, condemning,
# Nearest to state: esque, conifers, months, interception, jj, mammoths, testifies, securely,
# Nearest to at: in, liner, during, of, paused, attenuation, from, toxin,
# Nearest to d: totoro, hall, lune, american, heliports, b, detoxification, matsui,
# Nearest to for: with, dramatist, eds, hessen, without, reprinted, voss, in,
# Nearest to a: the, this, weight, continually, rockville, bronze, wf, ya,
# Nearest to between: gba, recife, in, warren, into, sura, with, canids,
# Nearest to see: spotlight, counters, is, btu, became, ejaculation, euros, honorable,
# Nearest to such: portsmouth, sb, hagelin, karaite, tumours, earned, gizzard, known,
# Nearest to nine: eight, seven, six, five, zero, four, three, two,
# Nearest to many: some, informatics, most, rosalyn, intuitionism, motherland, meteorites, bu,
# Nearest to an: personage, entrepot, the, inheritors, unstated, guignol, households, gondwana,
# Average loss at step 12000: 3.608206
# Average loss at step 14000: 3.570104
# Average loss at step 16000: 3.412324
# Average loss at step 18000: 3.457976
# Average loss at step 20000: 3.542024
# Nearest to were: are, was, had, have, be, is, by, sternberg,
# Nearest to th: litres, one, treads, nubian, sedgwick, caliph, guerilla, subsidized,
# Nearest to most: some, many, econometric, omri, catherine, more, latter, qinghai,
# Nearest to b: d, varsity, haer, lune, matsui, moravia, homeland, vagantes,
# Nearest to on: in, upon, messier, afterthought, xhtml, federico, geography, during,
# Nearest to state: esque, jj, kowloon, energetic, conifers, flatted, yu, velocity,
# Nearest to at: in, during, jasmuheen, from, coloureds, is, and, paused,
# Nearest to d: b, totoro, matsui, lune, hall, weights, detoxification, haer,
# Nearest to for: without, of, as, landmine, in, expanses, with, unorganized,
# Nearest to a: the, rockville, wonderswan, this, plebs, any, wf, continually,
# Nearest to between: from, into, with, gba, mosaic, warren, sura, polyidus,
# Nearest to see: boo, compares, deceiving, acura, interfacing, elite, melcher, are,
# Nearest to such: these, known, restrained, well, sb, friendships, hagelin, tyrannical,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to many: some, several, these, other, all, most, various, informatics,
# Nearest to an: personage, gondwana, entrepot, unstated, inheritors, compressing, depths, another,
# Average loss at step 22000: 3.505088
# Average loss at step 24000: 3.490224
# Average loss at step 26000: 3.480098
# Average loss at step 28000: 3.481242
# Average loss at step 30000: 3.505268
# Nearest to were: are, have, was, had, by, is, hickman, be,
# Nearest to th: litres, one, rd, treads, eight, nubian, st, cip,
# Nearest to most: many, some, more, omri, byrd, qinghai, econometric, contorted,
# Nearest to b: d, lune, haer, varsity, abdel, underemployment, phane, waveform,
# Nearest to on: upon, in, through, geography, afterthought, from, against, ischemic,
# Nearest to state: esque, kowloon, interception, energetic, testifies, rheumatism, angkor, yale,
# Nearest to at: in, during, amongst, handicraft, under, near, rulebook, granular,
# Nearest to d: b, totoro, lune, matsui, detoxification, hall, mirage, vagantes,
# Nearest to for: expanses, when, without, with, dmoz, after, by, mcs,
# Nearest to a: any, no, the, hamdi, rockville, continually, landholdings, bcp,
# Nearest to between: with, from, in, into, about, gba, mosaic, girlfriends,
# Nearest to see: is, but, compares, list, include, deceiving, redirect, boo,
# Nearest to such: well, these, restrained, known, sb, hagelin, karaite, tyrannical,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to many: some, several, these, most, all, various, peripatetic, other,
# Nearest to an: gondwana, entrepot, another, personage, jinx, the, inheritors, compressing,
# Average loss at step 32000: 3.504690
# Average loss at step 34000: 3.491462
# Average loss at step 36000: 3.459511
# Average loss at step 38000: 3.301988
# Average loss at step 40000: 3.429896
# Nearest to were: are, have, was, had, be, those, while, include,
# Nearest to th: litres, st, rd, treads, cot, imperfections, nd, guerilla,
# Nearest to most: more, many, omri, some, byrd, bundles, very, desktop,
# Nearest to b: d, waveform, furlong, r, kushan, lune, c, totoro,
# Nearest to on: upon, federico, at, in, during, afterthought, hammersmith, boudinot,
# Nearest to state: ateneo, testifies, kowloon, level, energetic, congress, notational, velocity,
# Nearest to at: during, on, near, liner, handicraft, in, attenuation, phenomenal,
# Nearest to d: b, totoro, lune, mirage, mencken, limbic, matsui, inordinate,
# Nearest to for: in, expanses, campaigners, alleviating, without, of, albarn, if,
# Nearest to a: the, another, bcp, any, jati, ludi, belatedly, broca,
# Nearest to between: into, with, over, from, through, against, gba, mid,
# Nearest to see: list, include, knowledgeable, deceiving, ulaanbaatar, but, superseded, sergey,
# Nearest to such: these, well, known, including, restrained, friendships, viewed, hagelin,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to many: some, several, these, various, those, most, peripatetic, other,
# Nearest to an: entrepot, another, inheritors, gondwana, orcas, guignol, linus, personage,
# Average loss at step 42000: 3.433052
# Average loss at step 44000: 3.454173
# Average loss at step 46000: 3.453026
# Average loss at step 48000: 3.349781
# Average loss at step 50000: 3.387595
# Nearest to were: are, have, was, had, those, be, being, stjepan,
# Nearest to th: litres, one, rd, three, nd, ricardo, calvinists, treads,
# Nearest to most: more, some, many, desktop, retort, omri, latter, disproved,
# Nearest to b: d, f, r, waveform, c, k, totoro, furlong,
# Nearest to on: upon, in, through, federico, at, from, alerted, afterthought,
# Nearest to state: rheumatism, testifies, kingdom, gambit, corporate, states, energetic, level,
# Nearest to at: during, on, near, in, liner, jasmuheen, under, handicraft,
# Nearest to d: b, totoro, lune, limbic, mencken, demo, jitsu, mirage,
# Nearest to for: expanses, alleviating, classically, dmoz, albarn, while, cottages, tiananmen,
# Nearest to a: another, the, continually, any, bcp, jati, presbyter, no,
# Nearest to between: with, in, into, against, through, across, over, gba,
# Nearest to see: include, list, but, scatter, compares, deceiving, lackey, teddy,
# Nearest to such: well, these, known, many, restrained, friendships, viewed, including,
# Nearest to nine: seven, eight, six, four, five, three, zero, two,
# Nearest to many: some, several, these, various, those, such, both, other,
# Nearest to an: entrepot, jinx, gondwana, the, upa, guignol, orcas, reversal,
# Average loss at step 52000: 3.438003
# Average loss at step 54000: 3.433676
# Average loss at step 56000: 3.442323
# Average loss at step 58000: 3.402365
# Average loss at step 60000: 3.397796
# Nearest to were: are, have, was, including, had, those, although, adrienne,
# Nearest to th: litres, six, eight, seven, rd, nd, st, calvinists,
# Nearest to most: more, some, many, especially, latter, desktop, omri, belief,
# Nearest to b: d, f, c, r, k, totoro, waveform, furlong,
# Nearest to on: upon, through, in, afterthought, messier, lambdamoo, misskelley, federico,
# Nearest to state: rheumatism, gambit, majority, kowloon, corporate, testifies, government, kingdom,
# Nearest to at: during, jasmuheen, after, near, phenomenal, in, nobel, transplants,
# Nearest to d: b, totoro, lune, linus, mirage, hy, matsui, limbic,
# Nearest to for: including, without, of, alleviating, campaigners, expanses, insignificant, if,
# Nearest to a: any, the, another, continually, bcp, belatedly, adenine, thymus,
# Nearest to between: with, among, within, over, gba, across, concerning, through,
# Nearest to see: include, list, but, external, islamic, can, endgame, compares,
# Nearest to such: these, known, well, including, many, hagelin, restrained, friendships,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to many: some, several, these, various, other, both, most, those,
# Nearest to an: entrepot, inheritors, jinx, orcas, another, personage, gondwana, linus,
# Average loss at step 62000: 3.244771
# Average loss at step 64000: 3.254600
# Average loss at step 66000: 3.405342
# Average loss at step 68000: 3.392611
# Average loss at step 70000: 3.358352
# Nearest to were: are, was, have, had, be, including, although, adrienne,
# Nearest to th: litres, twentieth, rd, bc, st, nd, one, ricardo,
# Nearest to most: more, many, less, especially, some, among, particularly, very,
# Nearest to b: d, f, r, totoro, x, furlong, heralds, untested,
# Nearest to on: upon, through, in, federico, at, into, with, under,
# Nearest to state: government, states, kingdom, northumbrian, city, rheumatism, yale, namco,
# Nearest to at: during, near, in, on, rulebook, jasmuheen, phenomenal, sachsen,
# Nearest to d: b, totoro, lune, mirage, matsui, linus, demo, mencken,
# Nearest to for: without, including, albarn, in, campaigners, against, while, alleviating,
# Nearest to a: the, another, any, hamdi, continually, bcp, landholdings, quite,
# Nearest to between: with, among, within, in, through, from, gesellschaft, across,
# Nearest to see: include, list, teddy, but, according, scatter, deceiving, compares,
# Nearest to such: these, well, many, including, known, certain, restrained, hagelin,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to many: some, several, these, various, all, most, such, both,
# Nearest to an: linus, contraception, inheritors, orcas, gondwana, the, jinx, quickdraw,
# Average loss at step 72000: 3.380576
# Average loss at step 74000: 3.350214
# Average loss at step 76000: 3.316696
# Average loss at step 78000: 3.356756
# Average loss at step 80000: 3.382339
# Nearest to were: are, had, have, was, those, include, although, dashiell,
# Nearest to th: litres, rd, cyg, twentieth, nd, one, bc, kilometer,
# Nearest to most: more, many, especially, some, among, less, retort, particularly,
# Nearest to b: d, f, r, c, totoro, furlong, entomologist, heralds,
# Nearest to on: upon, in, through, at, under, messier, federico, defines,
# Nearest to state: city, states, region, majority, rheumatism, kingdom, government, emphases,
# Nearest to at: in, on, during, within, after, phenomenal, erne, alerting,
# Nearest to d: b, totoro, int, lune, p, mencken, elwes, matsui,
# Nearest to for: provost, expanses, albarn, criticizing, pyle, tricolour, including, campaigners,
# Nearest to a: another, continually, hamdi, any, the, thymus, bcp, ludi,
# Nearest to between: among, within, with, over, through, mid, gba, across,
# Nearest to see: include, list, but, teddy, prior, includes, according, compares,
# Nearest to such: well, these, hagelin, viewed, certain, arecibo, friendships, including,
# Nearest to nine: eight, seven, five, six, four, three, zero, one,
# Nearest to many: some, several, various, these, most, both, all, numerous,
# Nearest to an: linus, entrepot, jinx, corresponded, contraception, inheritors, gondwana, another,
# Average loss at step 82000: 3.410396
# Average loss at step 84000: 3.410717
# Average loss at step 86000: 3.386703
# Average loss at step 88000: 3.352435
# Average loss at step 90000: 3.365616
# Nearest to were: are, had, have, was, these, those, although, innumerable,
# Nearest to th: litres, one, seven, st, twentieth, nd, cyg, ricardo,
# Nearest to most: more, some, especially, many, less, among, particularly, retort,
# Nearest to b: d, f, entomologist, umno, r, distress, c, k,
# Nearest to on: upon, messier, under, through, at, in, afterthought, into,
# Nearest to state: city, states, rheumatism, caesarion, government, majority, emphases, bangladeshi,
# Nearest to at: during, near, on, in, after, xhtml, ndnis, within,
# Nearest to d: b, totoro, linus, lune, int, polyethylene, mencken, detoxification,
# Nearest to for: of, without, dmoz, including, landmine, after, tiananmen, while,
# Nearest to a: another, hamdi, any, continually, the, jamming, bcp, emedicine,
# Nearest to between: with, among, within, through, from, mid, over, concerning,
# Nearest to see: include, list, includes, refers, com, teddy, but, cameron,
# Nearest to such: well, known, these, friendships, certain, follows, including, restrained,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to many: some, several, various, these, all, most, numerous, both,
# Nearest to an: inheritors, entrepot, linus, gondwana, jinx, tgs, another, orcas,
# Average loss at step 92000: 3.398627
# Average loss at step 94000: 3.258826
# Average loss at step 96000: 3.357160
# Average loss at step 98000: 3.245484
# Average loss at step 100000: 3.354190
# Nearest to were: are, have, was, these, had, those, although, papier,
# Nearest to th: nd, litres, twentieth, rd, sven, fourth, bc, cyg,
# Nearest to most: more, especially, less, among, desktop, many, oscillation, retort,
# Nearest to b: d, totoro, moravia, entomologist, publicize, umno, rod, poz,
# Nearest to on: upon, through, at, in, around, under, federico, against,
# Nearest to state: city, states, educating, caesarion, rheumatism, majority, testifies, bangladeshi,
# Nearest to at: on, near, in, during, after, xxii, randall, ennio,
# Nearest to d: b, totoro, q, mirage, limbic, macau, whore, azali,
# Nearest to for: when, without, including, after, albarn, if, insignificant, against,
# Nearest to a: another, any, the, hamdi, landholdings, presbyter, continually, jamming,
# Nearest to between: among, with, within, over, through, venetian, mid, concerning,
# Nearest to see: list, include, links, com, includes, external, references, endgame,
# Nearest to such: well, known, certain, these, many, including, friendships, viewed,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to many: several, some, various, these, all, numerous, those, few,
# Nearest to an: entrepot, gondwana, another, inheritors, linus, depths, jinx, hub,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # Get inputs and label
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # Get new data to buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_size in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, bag_window=bag_size)
    print('\nwith bag_window = %d:' % (bag_size))
    print('    batch:', [[reverse_dictionary[d] for d in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Use tf.reduce_sum to combine the input data

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.208561
# Nearest to i: practically, antietam, saloon, francais, fatigue, nonmetals, narrowed, bother,
# Nearest to during: ruins, fertile, humiliated, holmium, grundlagen, keywork, csf, sardonic,
# Nearest to by: georgi, quarks, screenplay, tiananmen, axle, montparnasse, approves, fabled,
# Nearest to on: rdx, lle, soto, pusan, hexameter, gardener, lausanne, gluing,
# Nearest to new: existentialist, transparent, him, combinations, cementing, hol, info, botham,
# Nearest to four: analogy, chin, handler, unjustified, halld, italiana, lugh, wins,
# Nearest to their: aas, dispose, compressing, paget, weinberger, megabyte, dragging, carpetbaggers,
# Nearest to to: psychotropic, popularised, geospatial, curtailed, learns, retailers, anhalt, intervened,
# Nearest to at: ufa, hardin, amur, unreal, briefcase, heats, hat, pfp,
# Nearest to into: waited, pendants, profit, enhanced, platt, orville, capoeiristas, solicitor,
# Nearest to there: releasing, does, longstreet, hymenoptera, normalized, throughput, mmx, veered,
# Nearest to is: exoskeleton, bandleader, childhood, abolishes, divers, properties, oddities, prepared,
# Nearest to so: prosecution, figurines, ausgleich, pantheon, assailants, rate, mushrooms, leicester,
# Nearest to b: licensed, debut, excuses, kayaks, intermarriages, resonances, post, amerigo,
# Nearest to than: unplugged, roderick, knowing, concorde, trypanosoma, durable, admiralty, nationality,
# Nearest to but: sectarianism, wushu, transfusion, sihanouk, haag, blackwell, impossible, retrieving,
# Average loss at step 2000: 4.594542
# Average loss at step 4000: 3.951220
# Average loss at step 6000: 3.710852
# Average loss at step 8000: 3.528312
# Average loss at step 10000: 3.469930
# Nearest to i: ii, contae, podium, socony, c, rachel, mda, woollen,
# Nearest to during: in, before, from, after, macho, ceylon, irrelevent, alcohols,
# Nearest to by: pledged, oliphant, unconfirmed, under, bursa, knudsen, civitas, have,
# Nearest to on: from, slope, likened, through, ammo, origination, immortal, hammers,
# Nearest to new: catwoman, divisors, baghdad, aerodynamic, septimania, esr, atwood, psychiatrists,
# Nearest to four: seven, five, zero, three, six, eight, nine, two,
# Nearest to their: his, its, her, the, cyanide, humbert, nautilus, pretend,
# Nearest to to: may, would, can, will, contrapuntal, elicit, brzezinski, cannot,
# Nearest to at: in, tempe, sonar, unreal, before, correctness, heats, pn,
# Nearest to into: tatar, mattered, when, mjf, unscrupulous, in, waited, blasting,
# Nearest to there: it, they, listings, bonzo, discovering, these, divided, sears,
# Nearest to is: was, are, has, distressing, filming, scruggs, became, optimizations,
# Nearest to so: rasmussen, cic, semitone, told, cruiser, ezra, sauk, walk,
# Nearest to b: d, django, nikos, busy, streamlining, taxis, extinguished, pitman,
# Nearest to than: or, sobriety, staffs, ly, with, unplugged, and, banjos,
# Nearest to but: however, regimen, and, patrimony, representation, huber, crocker, lactamase,
# Average loss at step 12000: 3.490982
# Average loss at step 14000: 3.433823
# Average loss at step 16000: 3.439510
# Average loss at step 18000: 3.402824
# Average loss at step 20000: 3.214457
# Nearest to i: ii, we, g, woollen, untested, scanty, nemours, colloidal,
# Nearest to during: in, since, after, before, throughout, until, against, disrespectful,
# Nearest to by: hitchhikers, oliphant, when, among, peninsular, ganymede, equalize, prejudiced,
# Nearest to on: upon, tobias, in, through, commissars, likened, screenshots, atlanteans,
# Nearest to new: stacked, labia, arkham, catwoman, grok, falco, atwood, aerodynamic,
# Nearest to four: three, five, seven, six, eight, nine, two, zero,
# Nearest to their: its, his, her, the, cyanide, our, humbert, sst,
# Nearest to to: will, may, must, would, can, could, bleak, might,
# Nearest to at: caterpillars, over, during, around, groundbreaking, near, rested, sonar,
# Nearest to into: through, off, from, sportscaster, tatar, when, mattered, resurrecting,
# Nearest to there: they, longer, these, it, bonzo, considered, asserting, discovering,
# Nearest to is: was, are, became, were, has, means, makes, spr,
# Nearest to so: obtainable, exponents, believe, rulemaking, duncan, russ, chemotherapeutic, sauk,
# Nearest to b: d, fricative, r, lactose, doughnuts, burglar, devo, amazement,
# Nearest to than: or, workplace, modafinil, haddock, ly, kh, lande, requires,
# Nearest to but: however, and, although, while, though, sarabande, turntable, crocker,
# Average loss at step 22000: 3.361574
# Average loss at step 24000: 3.297919
# Average loss at step 26000: 3.257073
# Average loss at step 28000: 3.282997
# Average loss at step 30000: 3.230837
# Nearest to i: g, ii, you, we, exploits, bertram, canceled, rijeka,
# Nearest to during: before, throughout, since, after, in, until, over, despite,
# Nearest to by: knudsen, iraqi, prejudiced, through, when, hominem, under, fiftieth,
# Nearest to on: upon, about, through, in, rout, mallory, tokugawa, moveable,
# Nearest to new: arkham, memorable, old, aerodynamic, grok, septimania, special, suitor,
# Nearest to four: six, eight, five, three, seven, nine, zero, two,
# Nearest to their: its, his, her, the, detectable, our, peck, pretend,
# Nearest to to: would, might, will, contrapuntal, could, must, should, can,
# Nearest to at: hardin, during, intimidating, surplus, near, when, before, tempe,
# Nearest to into: through, from, airstream, tatar, between, mattered, discharging, within,
# Nearest to there: they, it, longer, marcantonio, bonzo, which, considered, listings,
# Nearest to is: was, became, are, makes, has, remains, becomes, were,
# Nearest to so: lexicography, chemotherapeutic, alkanes, exponents, clausewitz, paget, then, motions,
# Nearest to b: single, straddle, d, moderator, thyestes, hiroshi, arbuthnot, l,
# Nearest to than: but, or, ly, contends, mythos, powerpoint, haddock, sobriety,
# Nearest to but: than, yet, and, see, although, however, until, belatedly,
# Average loss at step 32000: 3.015343
# Average loss at step 34000: 3.199433
# Average loss at step 36000: 3.188339
# Average loss at step 38000: 3.172836
# Average loss at step 40000: 3.161210
# Nearest to i: ii, g, we, you, groundbreaking, iv, susan, maths,
# Nearest to during: throughout, in, after, since, before, until, despite, against,
# Nearest to by: when, from, oliphant, with, brutus, amazons, using, ganymede,
# Nearest to on: upon, through, within, spleen, in, hammers, catalogues, rout,
# Nearest to new: septimania, stacked, submits, suitor, arkham, special, aerodynamic, commercially,
# Nearest to four: six, seven, three, five, eight, zero, two, nine,
# Nearest to their: its, his, her, the, your, my, our, humbert,
# Nearest to to: cannot, will, would, might, could, imprints, may, impeach,
# Nearest to at: when, sheridan, tempe, during, intimidating, near, outbound, before,
# Nearest to into: through, within, from, between, tatar, toward, out, mattered,
# Nearest to there: longer, they, marcantonio, bonzo, these, listings, considered, forbidden,
# Nearest to is: was, are, makes, were, became, has, becomes, remains,
# Nearest to so: motions, chemotherapeutic, clausewitz, stated, paget, cheung, labial, alkanes,
# Nearest to b: c, d, x, solutes, devolution, sinn, coalesced, critiques,
# Nearest to than: or, ly, much, but, likely, aiming, sobriety, banjos,
# Nearest to but: although, however, see, projective, than, paisley, taboos, rajiv,
# Average loss at step 42000: 3.206594
# Average loss at step 44000: 3.139029
# Average loss at step 46000: 3.148028
# Average loss at step 48000: 3.059745
# Average loss at step 50000: 3.043861
# Nearest to i: g, you, we, ii, iii, canceled, sharm, scraps,
# Nearest to during: since, throughout, before, in, within, around, until, after,
# Nearest to by: ganymede, oliphant, when, before, emiliano, mast, prejudiced, irrelevent,
# Nearest to on: upon, through, behind, in, within, shelton, kongsberg, about,
# Nearest to new: different, septimania, aerodynamic, submits, catwoman, stacked, modern, old,
# Nearest to four: five, three, seven, six, eight, two, zero, nine,
# Nearest to their: its, his, her, our, your, the, my, pretend,
# Nearest to to: will, could, would, must, can, cannot, should, may,
# Nearest to at: near, during, in, when, gelre, intimidating, biking, pn,
# Nearest to into: within, through, from, off, between, around, toward, airstream,
# Nearest to there: they, it, marcantonio, bonzo, considered, listings, lovell, longer,
# Nearest to is: was, are, became, includes, contains, makes, were, has,
# Nearest to so: chemotherapeutic, clausewitz, pharaonic, thus, too, motions, note, overweight,
# Nearest to b: d, hopi, henryk, supercomputing, multithreading, thorax, bean, bundeswehr,
# Nearest to than: or, but, sobriety, ly, aiming, hand, and, haddock,
# Nearest to but: although, than, though, however, and, haarlem, taboos, macs,
# Average loss at step 52000: 3.103390
# Average loss at step 54000: 3.095909
# Average loss at step 56000: 2.915352
# Average loss at step 58000: 3.018018
# Average loss at step 60000: 3.049757
# Nearest to i: ii, iii, uncompromising, podium, retrieved, inline, nawaf, polls,
# Nearest to during: throughout, before, in, since, after, within, until, at,
# Nearest to by: under, through, hitchhikers, before, jock, multiplies, oliphant, signage,
# Nearest to on: upon, behind, through, in, around, at, about, eyesight,
# Nearest to new: different, septimania, specific, submits, romero, saya, major, special,
# Nearest to four: six, three, eight, seven, five, zero, nine, two,
# Nearest to their: its, his, her, our, your, the, those, my,
# Nearest to to: will, would, must, could, cannot, might, denominational, should,
# Nearest to at: near, during, sonar, on, in, intimidating, since, hardin,
# Nearest to into: through, within, from, off, discharging, between, onto, toward,
# Nearest to there: they, longer, marcantonio, bonzo, wifi, actually, it, lovell,
# Nearest to is: was, are, includes, makes, has, were, provides, became,
# Nearest to so: chemotherapeutic, too, sometimes, believe, aztlan, armalite, fact, exponents,
# Nearest to b: d, c, bean, carlson, dunant, q, z, coleridge,
# Nearest to than: or, but, ly, hand, like, murky, slick, and,
# Nearest to but: and, although, though, however, than, see, until, unconditional,
# Average loss at step 62000: 3.013740
# Average loss at step 64000: 2.918680
# Average loss at step 66000: 2.935299
# Average loss at step 68000: 2.960956
# Average loss at step 70000: 3.015971
# Nearest to i: you, ii, g, punishments, iii, we, highways, colonised,
# Nearest to during: in, before, throughout, after, until, despite, following, at,
# Nearest to by: through, prejudiced, had, hitchhikers, from, via, cannery, when,
# Nearest to on: upon, behind, onto, through, at, about, eyesight, philosophie,
# Nearest to new: special, different, decisive, specific, septimania, modern, fundamentals, labia,
# Nearest to four: five, six, seven, three, two, j, zero, eight,
# Nearest to their: its, his, her, your, our, the, my, these,
# Nearest to to: will, could, would, cannot, must, may, can, temporally,
# Nearest to at: near, during, in, around, on, sonar, alongside, accountancy,
# Nearest to into: within, through, toward, from, airstream, onto, navier, discharging,
# Nearest to there: marcantonio, they, longer, rout, precautionary, listings, lovell, forbidden,
# Nearest to is: was, makes, are, includes, becomes, remains, has, involves,
# Nearest to so: chemotherapeutic, believe, too, argued, fact, note, sometimes, labial,
# Nearest to b: d, henryk, prescott, meade, c, thorax, herbivorous, drilled,
# Nearest to than: but, ly, aiming, recently, contends, sobriety, reunification, or,
# Nearest to but: however, although, though, and, while, than, cay, oversaw,
# Average loss at step 72000: 2.932767
# Average loss at step 74000: 2.870026
# Average loss at step 76000: 3.001222
# Average loss at step 78000: 3.006173
# Average loss at step 80000: 2.842691
# Nearest to i: you, ii, we, they, iii, reforming, vi, iv,
# Nearest to during: throughout, after, since, at, before, in, until, within,
# Nearest to by: flickering, suzhou, without, before, hitchhikers, neocortex, multiplies, under,
# Nearest to on: upon, behind, through, tokugawa, in, cursive, towards, onto,
# Nearest to new: different, special, specific, decisive, aerodynamic, lew, memorable, large,
# Nearest to four: six, seven, five, three, eight, zero, nine, two,
# Nearest to their: its, his, your, her, our, the, my, themselves,
# Nearest to to: might, will, can, must, may, cannot, could, would,
# Nearest to at: during, near, unless, around, tempe, celtiberian, sonar, intimidating,
# Nearest to into: within, through, toward, onto, airstream, across, navier, towards,
# Nearest to there: they, longer, marcantonio, it, forbidden, wifi, he, she,
# Nearest to is: was, are, makes, includes, exists, becomes, became, provides,
# Nearest to so: chemotherapeutic, too, therefore, now, armalite, fact, sometimes, realized,
# Nearest to b: d, f, k, c, henryk, bean, nested, xxi,
# Nearest to than: or, ly, peshitta, unlike, contends, haddock, likely, hand,
# Nearest to but: however, although, though, see, or, until, because, and,
# Average loss at step 82000: 2.938837
# Average loss at step 84000: 2.904404
# Average loss at step 86000: 2.924095
# Average loss at step 88000: 2.939901
# Average loss at step 90000: 2.832695
# Nearest to i: g, we, you, ii, iv, cogito, comprehend, reforming,
# Nearest to during: throughout, after, in, at, before, until, since, within,
# Nearest to by: through, suzhou, xl, when, knudsen, from, zuse, via,
# Nearest to on: upon, through, behind, in, onto, across, into, near,
# Nearest to new: stacked, special, aerodynamic, stabilized, reinforce, single, thumbnail, divisors,
# Nearest to four: five, three, six, seven, eight, zero, two, nine,
# Nearest to their: its, his, our, her, your, the, my, whose,
# Nearest to to: will, cannot, must, might, should, may, can, towards,
# Nearest to at: near, during, around, sonar, alongside, tempe, pendulum, prisoner,
# Nearest to into: onto, within, through, across, off, toward, between, behind,
# Nearest to there: it, they, forbidden, she, considered, awarded, longer, marcantonio,
# Nearest to is: was, are, remains, makes, becomes, became, includes, provides,
# Nearest to so: chemotherapeutic, believe, sometimes, whispers, fact, armalite, too, westernized,
# Nearest to b: d, f, engel, solid, chemical, tibeto, mello, myra,
# Nearest to than: or, but, ly, much, accurately, distraught, unlike, aiming,
# Nearest to but: however, though, although, whereas, see, unlike, than, lynched,
# Average loss at step 92000: 2.898225
# Average loss at step 94000: 2.887143
# Average loss at step 96000: 2.710757
# Average loss at step 98000: 2.459290
# Average loss at step 100000: 2.711191
# Nearest to i: we, ii, iii, you, g, trist, uncompromising, woollen,
# Nearest to during: throughout, at, since, in, despite, until, after, around,
# Nearest to by: without, hitchhikers, multiplies, civitas, flickering, peninsular, potemkin, knudsen,
# Nearest to on: upon, in, behind, onto, tokugawa, shelton, philosophie, during,
# Nearest to new: thumbnail, septimania, stacked, hammersmith, special, aerodynamic, memorable, modern,
# Nearest to four: three, six, five, seven, eight, two, zero, nine,
# Nearest to their: its, his, her, our, your, whose, the, my,
# Nearest to to: would, must, can, cannot, will, could, may, towards,
# Nearest to at: during, near, around, in, throughout, alongside, vous, tempe,
# Nearest to into: through, across, onto, down, between, off, from, within,
# Nearest to there: they, longer, forbidden, marcantonio, it, resting, listings, he,
# Nearest to is: was, are, exists, became, remains, makes, becomes, includes,
# Nearest to so: believe, chemotherapeutic, fact, sometimes, whispers, bec, too, nails,
# Nearest to b: d, django, schema, pres, hospitalized, ancona, prescott, lycus,
# Nearest to than: or, distraught, hand, accurately, but, recently, precisely, ly,
# Nearest to but: however, while, although, and, though, whereas, until, furthermore,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
